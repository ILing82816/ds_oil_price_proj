# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('D:/USA 2020 summer/Machine Learning/ds_oil_price_proj/data/data_clean.csv')
df.head()
# Out:
#         index     dj_price   dj_vloumn    sp_price    sp_vloumn  bond_1year  \
# 0  1995-05-01  4316.080078  27070000.0  514.260010  296830000.0        6.32
# 1  1995-05-02  4328.879883  26010000.0  514.859985  302560000.0        6.26
# 2  1995-05-03  4373.149902  33900000.0  520.479980  392370000.0        6.16
# 3  1995-05-04  4359.660156  40000000.0  520.539978  434990000.0        6.10
# 4  1995-05-05  4343.399902  33640000.0  520.119995  342380000.0        5.96
#
#    bond_5year  bond_10year  bond_30year  monetary_base  ...  fed_fund  \
# 0        6.90         7.09         7.35       433334.0  ...      6.10
# 1        6.83         7.04         7.33       433334.0  ...      6.01
# 2        6.73         6.96         7.25       433334.0  ...      6.00
# 3        6.63         6.85         7.15       433334.0  ...      6.01
# 4        6.42         6.69         7.02       433334.0  ...      5.98
#
#    brent_price  brent_volumn  wti_price  wti_volumn  Oil_Contract  \
# ...

# %%
df.columns
# Out:
# Index(['index', 'dj_price', 'dj_vloumn', 'sp_price', 'sp_vloumn', 'bond_1year',
#        'bond_5year', 'bond_10year', 'bond_30year', 'monetary_base', 'cpi',
#        'fed_fund', 'brent_price', 'brent_volumn', 'wti_price', 'wti_volumn',
#        'Oil_Contract', 'saudi_production', 'us_production', 'fuel_price',
#        'Gasoline_price'],
#       dtype='object')

# %%
df.describe()
# Out:
#            dj_price     dj_vloumn     sp_price     sp_vloumn   bond_1year  \
# count   6525.000000  6.525000e+03  6525.000000  6.525000e+03  6525.000000
# mean   12991.379458  1.917275e+08  1472.885475  2.631977e+09     2.513973
# std     5572.066625  1.207191e+08   620.114303  1.683158e+09     2.115308
# min     4316.080078  8.410000e+06   514.260010  1.499000e+07     0.080000
# 25%     9594.980469  9.404000e+07  1090.020020  1.152300e+09     0.420000
# 50%    11019.110352  1.886100e+08  1295.430054  2.738170e+09     2.010000
# 75%    16069.639648  2.580400e+08  1836.250000  3.733160e+09     4.870000
# max    29551.419922  2.190810e+09  3386.149902  1.145623e+10     6.440000
#
#         bond_5year  bond_10year  bond_30year  monetary_base          cpi  \
# count  6525.000000  6525.000000  6525.000000   6.525000e+03  6525.000000
# mean      3.321235     3.873928     4.505903   1.796145e+06   205.682228
# std       1.798711     1.539039     1.365802   1.358759e+06    31.847074
# ...

# %%
from pandas.plotting import register_matplotlib_converters
# Plot
fig, axes = plt.subplots(nrows=20, ncols=1, dpi=120, figsize=(6,25))
for i, ax in enumerate(axes.flatten()):
 data = df[df.columns[i+1]]
 ax.plot(data, color='red', linewidth=1)
# Decorations
 ax.set_title(df.columns[i+1])
 ax.xaxis.set_ticks_position('none')
 ax.yaxis.set_ticks_position('none')
 ax.spines['top'].set_alpha(0)
 ax.tick_params(labelsize=6)
plt.tight_layout();

# %%
from pandas.plotting import register_matplotlib_converters
# Plot
fig, axes = plt.subplots(nrows=20, ncols=1, dpi=120, figsize=(6,25))
for i, ax in enumerate(axes.flatten()):
    data = df[df.columns[i+1]]
    ax.hist(data, color='blue', linewidth=1)
# Decorations
    ax.set_title(df.columns[i+1])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines['top'].set_alpha(0)
    ax.tick_params(labelsize=6)
plt.tight_layout();
#plt.savefig('hist.png')

# %%
df[['dj_price', 'dj_vloumn', 'sp_price', 'sp_vloumn', 'bond_1year',
       'bond_5year', 'bond_10year', 'bond_30year']].corr()
# Out:
#              dj_price  dj_vloumn  sp_price  sp_vloumn  bond_1year  bond_5year  \
# dj_price     1.000000   0.354543  0.992004   0.451074   -0.418686   -0.569445
# dj_vloumn    0.354543   1.000000  0.321808   0.482272   -0.189192   -0.238881
# sp_price     0.992004   0.321808  1.000000   0.401829   -0.354204   -0.511723
# sp_vloumn    0.451074   0.482272  0.401829   1.000000   -0.687511   -0.740805
# bond_1year  -0.418686  -0.189192 -0.354204  -0.687511    1.000000    0.952403
# bond_5year  -0.569445  -0.238881 -0.511723  -0.740805    0.952403    1.000000
# bond_10year -0.694229  -0.275196 -0.649369  -0.731037    0.880319    0.976899
# bond_30year -0.800732  -0.297558 -0.770117  -0.735262    0.770833    0.901447
#
#              bond_10year  bond_30year
# dj_price       -0.694229    -0.800732
# dj_vloumn      -0.275196    -0.297558
# sp_price       -0.649369    -0.770117
# sp_vloumn      -0.731037    -0.735262
# bond_1year      0.880319     0.770833
# ...

# %%
#stock_bond
plt.figure(figsize=(14,10))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(df[['dj_price', 'dj_vloumn', 'sp_price', 'sp_vloumn', 'bond_1year',
       'bond_5year', 'bond_10year', 'bond_30year']].corr(), cmap = "BrBG",
linewidths=0.1, square=True, linecolor='white',
annot=True)
#plt.savefig('stock_bond_corr.png')
plt.show()

# %%
#stock_economic indicator
plt.figure(figsize=(14,10))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(df[['dj_price', 'dj_vloumn', 'sp_price', 'sp_vloumn', 'monetary_base', 'cpi',
       'fed_fund']].corr(), cmap = "BrBG",
linewidths=0.1, square=True, linecolor='white',
annot=True)
#plt.savefig('stock_bond_corr.png')
plt.show()

# %%
#bond_economic indicator
plt.figure(figsize=(14,10))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(df[['bond_1year','bond_5year', 'bond_10year', 'bond_30year', 'monetary_base', 'cpi',
       'fed_fund']].corr(), cmap = "BrBG",
linewidths=0.1, square=True, linecolor='white',
annot=True)
#plt.savefig('stock_bond_corr.png')
plt.show()

# %%
#stock_oil price and production
plt.figure(figsize=(14,10))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(df[['dj_price', 'dj_vloumn', 'sp_price', 'sp_vloumn', 'brent_price', 'brent_volumn', 'wti_price', 'wti_volumn',
       'Oil_Contract', 'saudi_production', 'us_production']].corr(), cmap = "BrBG",
linewidths=0.1, square=True, linecolor='white',
annot=True)
#plt.savefig('stock_bond_corr.png')
plt.show()

# %%
#bond_oil price and production
plt.figure(figsize=(14,10))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(df[['bond_1year','bond_5year', 'bond_10year', 'bond_30year', 'brent_price', 'brent_volumn', 'wti_price', 'wti_volumn',
       'Oil_Contract', 'saudi_production', 'us_production']].corr(), cmap = "BrBG",
linewidths=0.1, square=True, linecolor='white',
annot=True)
#plt.savefig('stock_bond_corr.png')
plt.show()

# %%
#economic indicator_oil price and production
plt.figure(figsize=(14,10))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(df[['monetary_base', 'cpi','fed_fund','brent_price', 'brent_volumn', 'wti_price', 'wti_volumn',
       'Oil_Contract', 'saudi_production', 'us_production']].corr(), cmap = "BrBG",
linewidths=0.1, square=True, linecolor='white',
annot=True)
#plt.savefig('stock_bond_corr.png')
plt.show()

# %%
#stock_target
plt.figure(figsize=(14,10))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(df[['dj_price', 'dj_vloumn', 'sp_price', 'sp_vloumn','fuel_price',
                'Gasoline_price' ]].corr(), cmap = "BrBG",
linewidths=0.1, square=True, linecolor='white',
annot=True)
#plt.savefig('stock_bond_corr.png')
plt.show()

# %%
#bond_target
plt.figure(figsize=(14,10))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(df[['bond_1year','bond_5year', 'bond_10year', 'bond_30year','fuel_price',
                'Gasoline_price' ]].corr(), cmap = "BrBG",
linewidths=0.1, square=True, linecolor='white',
annot=True)
#plt.savefig('stock_bond_corr.png')
plt.show()

# %%
#economic indicator_target
plt.figure(figsize=(14,10))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(df[['monetary_base', 'cpi','fed_fund','fuel_price',
                'Gasoline_price']].corr(), cmap = "BrBG",
linewidths=0.1, square=True, linecolor='white',
annot=True)
#plt.savefig('stock_bond_corr.png')
plt.show()

# %%
#oil price and production_target
plt.figure(figsize=(14,10))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(df[['brent_price', 'brent_volumn', 'wti_price', 'wti_volumn','Oil_Contract', 
                'saudi_production', 'us_production','fuel_price',
                'Gasoline_price']].corr(), cmap = "BrBG",
linewidths=0.1, square=True, linecolor='white',
annot=True)
#plt.savefig('stock_bond_corr.png')
plt.show()
